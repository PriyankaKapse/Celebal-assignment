# %%
#membership
List=[1,2,3,4,5,"Priyanka"]
a=10
b=4
if(a in List):
  print("a is present")
else:
  print("a is not present in List")

if(b in List):
  print("b is present in List")
else:
  print("b is not present in List")
# Out:
# a is not present in List
# b is present in List

# %%
#Iterating For loop
Name=["Priyanka","Akshini","Sampada","Aditi","Bhakti"]
for x in Name:
  print(x)
# Out:
# Priyanka
# Akshini
# Sampada
# Aditi
# Bhakti

# %%
#List
mylist=[1,23,45,"Priyanka",2,1,"Apple","College"]
print(mylist)
print(mylist[0])
print(mylist[1])
print(mylist[2])
print(mylist[3])
print(mylist[4])
print(mylist[5])
print(mylist[6])
print(mylist[7])
#negative indexing
print(mylist[-1])
print(mylist[-2])
print(mylist[-3])
print(mylist[-4])
print(mylist[-5])
print(mylist[-6])
print(mylist[-7])
print(mylist[-8])

#Slicing
print(mylist[1:])
print(mylist[2:])
print(mylist[3:])
print(mylist[4:])
print(mylist[5:])
print(mylist[6:])
print(mylist[7:])
print(mylist[:])
print(mylist[4:7])
print(mylist[0:4])
print(mylist[-4:-1])
print(mylist[-5:-3])

# %%
#Tuples
mytuple=(1,2,3,4,5,6,7,8,"Priyanka","Friends","Bag","Car","2")
print(mytuple)
print(mytuple[0])
print(mytuple[1])
print(mytuple[2])
print(mytuple[3])
print(mytuple[4])
print(mytuple[5])
print(mytuple[6])
print(mytuple[7])
print(mytuple[8])
print(mytuple[9])
print(mytuple[10])
print(mytuple[11])
print(mytuple[12])

#negative indexing
print(mytuple[-6])
print(mytuple[-4])
print(mytuple[-1])
print(mytuple[-3])
print(mytuple[-12])

#Slicing
print(mytuple[-8:-2])
print(mytuple[-5:-1])

# %%
#Strings
mystring="Hello,I Am Priyanka"
print(mystring)
print(mystring[5])
print(mystring[0])
print(mystring[1])
print(mystring[7])
print(mystring[9])


#Negative indexing
print(mystring[-7])
print(mystring[-15])

#Slicing
print(mystring[1:])
print(mystring[1:5])
print(mystring[11:18])
print(mystring[11:])
print(mystring[-3:-1])
print(mystring[-8:-5])

# %%
#Set
A={1,2,3,10,45,100,450,30,2,34,3,1,2,}
print(A)
A.add(500)
print(A)

myset={"priyanka","Hello","welcome"}
print(myset)
myset.add("Good,Morning")
print(myset)

# %%
#Dictionary
Dictionary={"Name":"priyanka","age":20,"College":"SCOE"}
print(Dictionary)
Dictionary["Class"]="TYBT"
print(Dictionary)
